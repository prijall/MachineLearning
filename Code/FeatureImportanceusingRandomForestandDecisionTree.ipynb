# %%
from sklearn.datasets import make_classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X, y= make_classification(n_samples=5, n_classes=2, n_features=2, n_informative=2, n_redundant=0, random_state=44)

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

plot_tree(clf)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[0] <= -0.842\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.625, 'x[1] <= -2.219\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.375, 'x[0] <= 0.689\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
clf.feature_importances_
# Out:
# array([0.86111111, 0.13888889])

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=2)
rf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
rf.feature_importances_
# Out:
# array([0.1875, 0.8125])

# %%
print(rf.estimators_[0].feature_importances_)
print(rf.estimators_[1].feature_importances_)
# Out:
# [0. 1.]
# [0.375 0.625]

# %%
print((1+0.625)/2)
# Out:
# 0.8125
